# %% [markdown]
# # Training and Visual Evaluation

# %%
import importlib
import gen_util
importlib.reload(gen_util)

gen_util.train_eval()
# Out:
# /opt/conda/envs/pytorch-py35/lib/python3.5/site-packages/scipy/ndimage/interpolation.py:568: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# shape: (73, 225, 225) | dtype: float64
# min: 0.0 | max: 1.0 | median 0.521767637031
# shape: (73, 225, 225) | dtype: float64
# min: 0.0 | max: 1.0 | median 0.339393939394
# x, y shapes: (16, 1, 32, 64, 64) (16, 1, 32, 64, 64)
# ctor: chek model
# iter:   0 | loss: 0.110573
# iter:   1 | loss: 0.073480
# iter:   2 | loss: 0.061032
# iter:   3 | loss: 0.052794
# iter:   4 | loss: 0.048836
# iter:   5 | loss: 0.045898
# iter:   6 | loss: 0.043196
# iter:   7 | loss: 0.041140
# iter:   8 | loss: 0.039664
# iter:   9 | loss: 0.038515
# iter:  10 | loss: 0.037536
# iter:  11 | loss: 0.036701
# iter:  12 | loss: 0.036004
# iter:  13 | loss: 0.035415
# iter:  14 | loss: 0.034905
# ...
