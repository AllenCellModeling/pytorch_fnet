# %% [markdown]
# ## Training on 5 images, testing on novel images
# To select z for display, the DNA channel is scanned for the z value that gives the largest cummulative image intensity.

# %%
# %cd /root/projects/nucleus_predictor
# %run load_eval --data_path data/tubulin_nobgsub --n_images 8 --load_path saved_models/few_files_long.p
# Out:
# /root/projects/nucleus_predictor
# loaded dataset split from: data/dataset_saves/tubulin_nobgsub.p
# DataSet from: data/tubulin_nobgsub
# percent_test: 0.1
# train/test/total: 516/57/573
# loading model: saved_models/few_files_long.p
# model load time: 109.8 s
# few_files_long | mult_chan: 32 | depth: 4
# TiffDataProvider: loading data/tubulin_nobgsub/3500000666_100X_20170303_E07_P31.czi
# /opt/conda/envs/pytorch-py35/lib/python3.5/site-packages/tifffile/tifffile.py:2642: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# /opt/conda/envs/pytorch-py35/lib/python3.5/site-packages/tifffile/tifffile.py:2577: UserWarning: unpack: string size must be a multiple of element size
#   warnings.warn("unpack: %s" % e)
# ...

# %%
# %cd /root/projects/nucleus_predictor
# %run display_log --log_path logs/few_files_long.csv --history 2
