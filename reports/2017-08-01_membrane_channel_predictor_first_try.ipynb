# %% [markdown]
# ## Bright-field to membrane channel prediction
# Membrane channel predictor was trained using the same dataset used on the DNA channel predictor.

# %%
# %cd /root/projects/nucleus_predictor
# Out:
# /root/projects/nucleus_predictor

# %%
# %run load_eval --data_path data/dataset_saves/ttf_memb_no_hots.ds --load_path saved_models/ttf_memb_no_hots_00.p
# Out:
# on GPU: 0
# loaded dataset from: data/dataset_saves/ttf_memb_no_hots.ds
# DataSet from: data/dataset_saves/ttf_memb_no_hots.ds
# file_tags: ('_trans.tif', '_memb.tif')
# active_set: test
# train/test/total: 15/3/18
# transforms: Resizer | factors: (0.97, 0.36, 0.36) => <function sub_mean_norm at 0x7f9ceef5a378>
#             Resizer | factors: (0.97, 0.36, 0.36) => <function sub_mean_norm at 0x7f9ceef5a378>
# loading checkpoint from: saved_models/ttf_memb_no_hots_00.p
# model load time: 3.0 s
# v5_nn | iter: 44931
# reading TIFs from data/no_hots/3500000523_100X_20170314_D04_P06.czi
# DEBUG: (51, 225, 333) (1, 1, 32, 224, 224)
# z displayed: [17]
# reading TIFs from data/no_hots/3500000523_100X_20170314_D07_P25.czi
# DEBUG: (53, 225, 333) (1, 1, 32, 224, 224)
# z displayed: [17]
# reading TIFs from data/no_hots/3500000523_100X_20170314_D08_P30.czi
# DEBUG: (46, 225, 333) (1, 1, 32, 224, 224)
# z displayed: [15]

# %%
# %run display_log.py --log_path logs/ttf_memb_no_hots_00.csv --history 0
