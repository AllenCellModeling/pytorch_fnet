# %%
# %cd /root/projects/nucleus_predictor
# %run load_eval --data_path data_2 --n_examples 16 --load_path saved_models/run_170628_155141.p
# Out:
# /root/projects/nucleus_predictor
# DataSet from: data_2
# percent_test: 0.1
# train/test/total: 516/57/573
# loading model: saved_models/run_170628_155141.p
# model load time: 106.1 s
# run_170628_155141 | mult_chan: 32 | depth: 4
# TiffDataProvider: loading data_2/3500000666_100X_20170303_E07_P31.czi
# /opt/conda/envs/pytorch-py35/lib/python3.5/site-packages/tifffile/tifffile.py:2642: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# /opt/conda/envs/pytorch-py35/lib/python3.5/site-packages/tifffile/tifffile.py:2577: UserWarning: unpack: string size must be a multiple of element size
#   warnings.warn("unpack: %s" % e)
# /opt/conda/envs/pytorch-py35/lib/python3.5/site-packages/scipy/ndimage/interpolation.py:568: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# ...

# %%
# %run display_log --log_path logs/run_170628_155141.csv --history 0
